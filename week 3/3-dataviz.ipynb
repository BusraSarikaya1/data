# %%
import numpy as np
import matplotlib.pyplot as pyplot
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns
import matplotlib.patches as mpatches

# %%
df  =  pd.DataFrame({
    'Group': ['A','B','C','D','E'],
    'Value': [1,5,4,3,9],
         

})

# %%
df
# Out:
#   Group  Value
# 0     A      1
# 1     B      5
# 2     C      4
# 3     D      3
# 4     E      9

# %%
plt.barh(y=df.Group, width=df.Value)  #Group" kategorilerini ve bu kategorilere ait "Value" değerlerini içeren bir veri çerçevesinden yatay çubuk grafik oluşturur ve bu grafik ekranda gösterilir.
# Out:
# <BarContainer object of 5 artists>

# %%
df=df.sort_values(by=['Value'])  #veri çerevesi value sutünuna göre oluşturuldu.
plt.barh(y=df.Group, 
         width=df.Value, 
         color=['red','blue'], 
         edgecolor='black',
         linewidth=3)
# Out:
# <BarContainer object of 5 artists>

# %%
df=df.sort_values(by=['Value'],ascending= False)  #verileri küçükten büyüğe sıralamk istersek ascending metodunu kullanabiliriz.
plt.barh(y=df.Group, 
         width=df.Value, 
         color= mcolors.TABLEAU_COLORS, 
         edgecolor='black',
         linewidth=3
         )
plt.show()

# %%
tips=sns.load_dataset('tips')  #Bu kod, Seaborn kütüphanesini kullanarak "tips" adlı önceden tanımlanmış bir veri kümesini yükler. Seaborn, veri görselleştirmesi için kullanılan bir Python kütüphanesidir ve genellikle Matplotlib üzerine inşa edilmiştir.
                               #sns.load_dataset('tips'): Seaborn'un load_dataset fonksiyonunu kullanarak "tips" adlı veri kümesini yükler. Bu veri kümesi, genellikle restoranlarda alınan bahşişlerle ilgili verileri içerir. tips adında bir Pandas DataFrame olarak döner.

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.set(style="darkgrid")  # seaborn un set stili kullanılarak grafik stili ayarlanır.
sns.barplot(               #seaborn un 'barplot'fonksiyonu kullanılarak çubuk grafik oluşturulur.
    x="total_bill",
    y="day",
    data=tips,
    color="cyan"
)
plt.figure(figsize=(18, 8))

# %%
smoker = tips[tips.smoker=='Yes']

# %%
bar2 = sns.barplot(
    x='day',
    y='total_bill',
    data=smoker,
    estimator=sum,
    errorbar=None,
    color='lightblue'
)

# %%
# 
g = sns.FacetGrid(tips, col="day", height=4, aspect=.5)
g.map(sns.barplot, "sex", "total_bill", order=["Male", "Female"])
"""sns.FacetGrid(tips, col="day", height=4, aspect=.5):
 FacetGrid sınıfını kullanarak çoklu yüzeyli bir çerçeve
oluşturur. tips veri kümesi üzerinde çalışacak ve "day" 
sütununa göre alt grafiklere ayrılacak. height ve aspect
parametreleri, her bir alt grafik (facet) için yükseklik
ve en boy oranını belirler.

g.map(sns.barplot, "sex", "total_bill", order=["Male", "Female"]): Oluşturulan 
çerçeve üzerinde barplot fonksiyonunu çağırır. Bu fonksiyon, her bir alt grafikte 
bir çubuk grafik oluşturur. "sex" sütununu x ekseni, "total_bill" sütununu y ekseni 
olarak kullanır ve çubuklar "Male" ve "Female" sırasına göre sıralanır. Bu şekilde, 
her bir gün için cinsiyetlere göre toplam hesapları gösteren bir çubuk grafik oluşturulur.

"""
# Out:
# 'sns.FacetGrid(tips, col="day", height=4, aspect=.5):\n FacetGrid sınıfını kullanarak çoklu yüzeyli bir çerçeve\noluşturur. tips veri kümesi üzerinde çalışacak ve "day" \nsütununa göre alt grafiklere ayrılacak. height ve aspect\nparametreleri, her bir alt grafik (facet) için yükseklik\nve en boy oranını belirler.\n\ng.map(sns.barplot, "sex", "total_bill", order=["Male", "Female"]): Oluşturulan \nçerçeve üzerinde barplot fonksiyonunu çağırır. Bu fonksiyon, her bir alt grafikte \nbir çubuk grafik oluşturur. "sex" sütununu x ekseni, "total_bill" sütununu y ekseni \nolarak kullanır ve çubuklar "Male" ve "Female" sırasına göre sıralanır. Bu şekilde, \nher bir gün için cinsiyetlere göre toplam hesapları gösteren bir çubuk grafik oluşturulur.\n\n'

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
total = tips.groupby('day')['total_bill'].sum().reset_index()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_37852\2479030589.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   total = tips.groupby('day')['total_bill'].sum().reset_index()

# %%
total
# Out:
#     day  total_bill
# 0  Thur     1096.33
# 1   Fri      325.88
# 2   Sat     1778.40
# 3   Sun     1627.16

# %%
bar1 = sns.barplot(x="day",  y="total_bill", data=total, color='darkblue')

# %%
smoker = tips[tips.smoker == 'Yes']   #
#Bu kod, "tips" veri kümesindeki "smoker
#sütunu değeri "Yes" olan gözlemleri seçer ve 
#bu gözlemleri içeren yeni bir veri çerçevesi 
#oluşturur. İşte kodun açıklaması#

# %%
smoker
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 56        38.01  3.00    Male    Yes  Sat  Dinner     4
# 58        11.24  1.76    Male    Yes  Sat  Dinner     2
# 60        20.29  3.21    Male    Yes  Sat  Dinner     2
# 61        13.81  2.00    Male    Yes  Sat  Dinner     2
# 62        11.02  1.98    Male    Yes  Sat  Dinner     2
# ..          ...   ...     ...    ...  ...     ...   ...
# 234       15.53  3.00    Male    Yes  Sat  Dinner     2
# 236       12.60  1.00    Male    Yes  Sat  Dinner     2
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
#
# [93 rows x 7 columns]

# %%
bar2 = sns.barplot(
    x='day',
    y='total_bill',
    data=smoker,
    estimator=sum,  # estimator için Çubuk grafikte çubukların yüksekliğini hesaplarken kullanılacak tahmini değeri belirtir. Bu durumda, her 
    gün için "total_bill" #sütunundaki değerlerin toplamı alınır.
    errorbar=None,
    color='lightblue'
)

# %%
bar1 = sns.barplot(x="day",  y="total_bill", data=total, color='darkblue')
bar2 = sns.barplot(
    x='day',
    y='total_bill',
    data=smoker,
    estimator=sum,
    errorbar=None,
    color='lightblue'
)

# %%
bar1 = sns.barplot(x="day",  y="total_bill", data=total, color='darkblue')
bar2 = sns.barplot(
    x='day',
    y='total_bill',
    data=smoker,
    estimator=sum,
    errorbar=None,
    color='lightblue'
)

# %%
top_bar = mpatches.Patch(color='darkblue', label='non-smoker')
bottom_bar = mpatches.Patch(color='lightblue', label='smoker = Yes')
plt.legend(handles=[top_bar, bottom_bar])
# legend fonksiyonu kullanılarak legend
#  (leyenda) eklenir. handles parametresi, 
# oluşturulan Patch nesnelerini içeren bir liste alır.
plt.show()

# %%
bar1 = sns.barplot(x="day",  y="total_bill", data=total, color='darkblue')
bar2 = sns.barplot(
    x='day',
    y='total_bill',
    data=smoker,
    estimator=sum,
    errorbar=None,
    color='lightblue'
)

top_bar = mpatches.Patch(color='darkblue', label='non-smoker')
bottom_bar = mpatches.Patch(color='lightblue', label='smoker = Yes')
plt.legend(handles=[top_bar, bottom_bar])
# legend fonksiyonu kullanılarak legend
#  (leyenda) eklenir. handles parametresi, 
# oluşturulan Patch nesnelerini içeren bir liste alır.
plt.show()

# %%
df_iris = sns.load_dataset('iris')

# %%
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import seaborn as sns
sns.histplot(data=df_iris, x='sepal_length', kde=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 import seaborn as sns
# ----> 2 sns.histplot(data=df_iris, x='sepal_length', kde=True)
#
# NameError: name 'df_iris' is not defined

# %%
sns.regplot(   #scatter plot oluşturmamızı sağlar
    x=df_iris['sepal_length'],
    y=df_iris['sepal_width'],
    marker= "*",
    line_kws={
        "color":"red",
        "alpha":0.6,
        "lw":5 
    },
    scatter_kws={
        "color":"darkblue",
        "s":50
    }
    )
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.lmplot(
    x='sepal_length',
    y='sepal_width',
    data=df_iris,
    hue="species"
    
)

# %%
sns.set_theme(style="white", palette="pastel")
sns.boxplot(x=df_iris['species'], y=df_iris['sepal_length'])
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
df_iris.boxplot(column='sepal_length', by='species')
plt.show()
