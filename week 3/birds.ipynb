# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches
import seaborn as sns
import numpy as np
import pandas as pd

# %%
birds_dataset=pd.read_csv('C:/DATA/data/covid_veri/birds.csv')

# %%
birds_dataset
# Out:
#                              Name          ScientificName  \
# 0    Black-bellied whistling-duck  Dendrocygna autumnalis
# 1          Fulvous whistling-duck     Dendrocygna bicolor
# 2                      Snow goose      Anser caerulescens
# 3                    Ross's goose            Anser rossii
# 4     Greater white-fronted goose         Anser albifrons
# ..                            ...                     ...
# 438                 Blue grosbeak      Passerina caerulea
# 439                Lazuli bunting        Passerina amoena
# 440                Indigo bunting        Passerina cyanea
# 441               Painted bunting         Passerina ciris
# 442                    Dickcissel         Spiza americana
#
#                   Category          Order        Family        Genus  \
# 0    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 1    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# ...

# %%
birds_dataset.head(n=10)
# Out:
#                            Name          ScientificName  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
# 3                  Ross's goose            Anser rossii
# 4   Greater white-fronted goose         Anser albifrons
# 5                         Brant         Branta bernicla
# 6                Cackling goose       Branta hutchinsii
# 7                  Canada goose       Branta canadensis
# 8                     Mute swan             Cygnus olor
# 9                Trumpeter swan       Cygnus buccinator
#
#                 Category         Order    Family        Genus  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 3  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# ...

# %%
birds_dataset.shape
# Out:
# (443, 13)

# %%
birds_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                443 non-null    object
#  1   ScientificName      443 non-null    object
#  2   Category            443 non-null    object
#  3   Order               443 non-null    object
#  4   Family              443 non-null    object
#  5   Genus               443 non-null    object
#  6   ConservationStatus  443 non-null    object
#  7   MinLength           443 non-null    float64
#  8   MaxLength           443 non-null    float64
#  9   MinBodyMass         443 non-null    float64
#  10  MaxBodyMass         443 non-null    float64
#  11  MinWingspan         443 non-null    float64
#  12  MaxWingspan         443 non-null    float64
# dtypes: float64(6), object(7)
# memory usage: 45.1+ KB

# %%
birds_dataset.describe()
# Out:
#         MinLength   MaxLength  MinBodyMass   MaxBodyMass  MinWingspan  \
# count  443.000000  443.000000   443.000000    443.000000   443.000000
# mean    28.536682   35.441986   327.938262    667.009752    58.557901
# std     20.319887   27.539772   779.680106   1655.682564   104.602369
# min      7.000000    8.900000     2.000000      3.000000     8.000000
# 25%     13.750000   16.000000    18.000000     28.000000    23.000000
# 50%     20.500000   25.000000    55.000000     89.000000    38.000000
# 75%     39.000000   46.000000   332.000000    593.000000    72.750000
# max    138.000000  180.000000  9200.000000  14300.000000  1800.000000
#
#        MaxWingspan
# count   443.000000
# mean     67.524492
# std     126.673177
# min      10.600000
# 25%      25.000000
# 50%      42.000000
# 75%      83.000000
# max    2300.000000

# %%
birds_dataset["MinLength"].describe()
# Out:
# count    443.000000
# mean      28.536682
# std       20.319887
# min        7.000000
# 25%       13.750000
# 50%       20.500000
# 75%       39.000000
# max      138.000000
# Name: MinLength, dtype: float64

# %%
birds_dataset["MinLength"].mean()
# Out:
# 28.53668171557562

# %%
birds_dataset["MinLength"].median()
# Out:
# 20.5

# %%
df1= pd.DataFrame(birds_dataset)

# %%
df1
# Out:
#                              Name          ScientificName  \
# 0    Black-bellied whistling-duck  Dendrocygna autumnalis
# 1          Fulvous whistling-duck     Dendrocygna bicolor
# 2                      Snow goose      Anser caerulescens
# 3                    Ross's goose            Anser rossii
# 4     Greater white-fronted goose         Anser albifrons
# ..                            ...                     ...
# 438                 Blue grosbeak      Passerina caerulea
# 439                Lazuli bunting        Passerina amoena
# 440                Indigo bunting        Passerina cyanea
# 441               Painted bunting         Passerina ciris
# 442                    Dickcissel         Spiza americana
#
#                   Category          Order        Family        Genus  \
# 0    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 1    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# ...

# %%
df1.groupby("ScientificName").sum()
# Out:
#                                            Name                  Category  \
# ScientificName
# Acanthis flammea                 Common redpoll  Finches/Euphonias/Allies
# Acanthis hornemanni               Hoary redpoll  Finches/Euphonias/Allies
# Accipiter cooperii                Cooper's hawk              Hawks/Eagles
# Accipiter gentilis             Northern goshawk              Hawks/Eagles
# Accipiter striatus           Sharp-shinned hawk              Hawks/Eagles
# ...                                         ...                       ...
# Zenaida macroura                  Mourning dove             Pigeons/Doves
# Zonotrichia albicollis   White-throated sparrow        New World sparrows
# Zonotrichia atricapilla  Golden-crowned sparrow        New World sparrows
# Zonotrichia leucophrys    White-crowned sparrow        New World sparrows
# Zonotrichia querula            Harris's sparrow        New World sparrows
#
# ...

# %%
df1[df1["Category"]=="Hawks/Eagles"]
# Out:
#                     Name            ScientificName      Category  \
# 202    White-tailed kite           Elanus leucurus  Hawks/Eagles
# 203  Swallow-tailed kite      Elanoides forficatus  Hawks/Eagles
# 204         Golden eagle         Aquila chrysaetos  Hawks/Eagles
# 205     Northern harrier          Circus hudsonius  Hawks/Eagles
# 206   Sharp-shinned hawk        Accipiter striatus  Hawks/Eagles
# 207        Cooper's hawk        Accipiter cooperii  Hawks/Eagles
# 208     Northern goshawk        Accipiter gentilis  Hawks/Eagles
# 209           Bald eagle  Haliaeetus leucocephalus  Hawks/Eagles
# 210     Mississippi kite  Ictinia mississippiensis  Hawks/Eagles
# 211  Red-shouldered hawk            Buteo lineatus  Hawks/Eagles
# 212    Broad-winged hawk         Buteo platypterus  Hawks/Eagles
# 213      Swainson's hawk           Buteo swainsoni  Hawks/Eagles
# 214      Red-tailed hawk         Buteo jamaicensis  Hawks/Eagles
# ...

# %%
df1[df1["Family"]=="Accipitridae"].value_counts()
# Out:
# Name                 ScientificName            Category      Order            Family        Genus       ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  MinWingspan  MaxWingspan
# Bald eagle           Haliaeetus leucocephalus  Hawks/Eagles  Accipitriformes  Accipitridae  Haliaeetus  LC                  70.0       102.0      3000.0       6300.0       1800.0       2300.0         1
# Broad-winged hawk    Buteo platypterus         Hawks/Eagles  Accipitriformes  Accipitridae  Buteo       LC                  32.0       44.0       265.0        560.0        74.0         100.0          1
# Cooper's hawk        Accipiter cooperii        Hawks/Eagles  Accipitriformes  Accipitridae  Accipiter   LC                  35.0       50.0       215.0        701.0        62.0         99.0           1
# ...

# %%
birds_dataset["MinBodyMass"].plot(kind='box', vert=False, figsize=(10,6))
# Out:
# <Axes: >

# %%
birds_dataset['MaxLength'].plot(kind='density', figsize=(10,6))
# Out:
# <Axes: ylabel='Density'>

# %%
ax = birds_dataset['MinBodyMass'].plot(kind='density', figsize=(10,6))
ax.axvline(birds_dataset['MinBodyMass'].mean(), color='red')
ax.axvline(birds_dataset['MinBodyMass'].median(), color='green')

# %%
birds_dataset['Genus'].value_counts() #unique değerlerin kaç gösterildiğini gösterir.
# Out:
# Genus
# Setophaga     22
# Calidris      15
# Larus         10
# Vireo          7
# Buteo          6
#               ..
# Ixobrychus     1
# Bubulcus       1
# Butorides      1
# Nycticorax     1
# Spiza          1
# Name: count, Length: 238, dtype: int64

# %%
sns.set(style="darkgrid")
sns.barplot(
    x="Family",
    y="Genus",        
    data=birds_dataset,
    color="cyan"
)
plt.figure(figsize=(18,8))

# %%
g = sns.FacetGrid(birds_dataset, col="Category",
                   height=4, aspect=.5)
g.map(sns.barplot, "Genus", "MinBodyMass", order=["Dendrocygna", "Anser"])

# %%
total_1 = birds_dataset.groupby('Category')['Genus'].sum().reset_index()

# %%
total_1
# Out:
#                            Category  \
# 0               Auks/Murres/Puffins
# 1                         Barn-owls
# 2                  Cardinals/Allies
# 3                  Cormorants/Shags
# 4                            Cranes
# 5                Crows/Jays/Magpies
# 6                           Cuckoos
# 7                           Dippers
# 8             Ducks/Geese/Waterfowl
# 9                Falcons /Caracaras
# 10         Finches/Euphonias/Allies
# 11                     Frigatebirds
# 12                     Gnatcatchers
# 13                           Grebes
# 14             Gulls/Terns/Skimmers
# 15                     Hawks/Eagles
# 16           Herons/Egrets/Bitterns
# 17                     Hummingbirds
# 18                Ibises/Spoonbills
# 19                      Kingfishers
# 20                         Kinglets
# 21                            Larks
# 22          Longspurs/Snow buntings
# 23                            Loons
# 24           Mockingbirds/Thrashers
# ...

# %%
bar1 = sns.barplot(x="Category",  y="Genus", data=total, color='darkblue')
