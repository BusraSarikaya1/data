# %% [markdown]
# Week2

# %% [markdown]
# Exercise:

# %%
import pandas as pd
import numpy as np

# %%
infected_dataset=pd.read_csv('C:/DATA/data/covid_veri/time_series_covid19_confirmed_global.csv')

# %%
infected_dataset
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 263            NaN                Comoros -11.645500  43.333300        0
# 264            NaN             Tajikistan  38.861034  71.276093        0
# 265            NaN                Lesotho -29.609988  28.233608        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  \
# ...

# %%
df1= pd.DataFrame(infected_dataset)      
df1["Country/Region"].value_counts()       # her ülkeye ait kaç tane sütün var.
# Out:
# Country/Region
# China             33
# Canada            14
# United Kingdom    11
# France            11
# Australia          8
#                   ..
# Honduras           1
# Hungary            1
# Iceland            1
# India              1
# Lesotho            1
# Name: count, Length: 188, dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Columns: 150 entries, Province/State to 6/15/20
# dtypes: float64(2), int64(146), object(2)
# memory usage: 311.8+ KB

# %%
print(infected_dataset.head(10))   # ilk 10 satırı döndürdü.
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  \
# 0        0        0        0        0        0        0  ...   19551   20342
# ...

# %%
df1["Province/State"].value_counts()
# Out:
# Province/State
# Australian Capital Territory    1
# Qinghai                         1
# Reunion                         1
# New Caledonia                   1
# Mayotte                         1
#                                ..
# Guizhou                         1
# Guangxi                         1
# Guangdong                       1
# Gansu                           1
# Saint Pierre and Miquelon       1
# Name: count, Length: 81, dtype: int64

# %%
df1= pd.DataFrame(infected_dataset)

# %%
df1
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 263            NaN                Comoros -11.645500  43.333300        0
# 264            NaN             Tajikistan  38.861034  71.276093        0
# 265            NaN                Lesotho -29.609988  28.233608        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  \
# ...

# %%
CountryGroup = df1.groupby("Country/Region")

# %%
CountryGroup

# %%
CountryGroup.sum()
# Out:
#                    Province/State        Lat       Long  1/22/20  1/23/20  \
# Country/Region
# Afghanistan                     0  33.000000  65.000000        0        0
# Albania                         0  41.153300  20.168300        0        0
# Algeria                         0  28.033900   1.659600        0        0
# Andorra                         0  42.506300   1.521800        0        0
# Angola                          0 -11.202700  17.873900        0        0
# ...                           ...        ...        ...      ...      ...
# West Bank and Gaza              0  31.952200  35.233200        0        0
# Western Sahara                  0  24.215500 -12.885800        0        0
# Yemen                           0  15.552727  48.516388        0        0
# Zambia                          0 -15.416700  28.283300        0        0
# Zimbabwe                        0 -20.000000  30.000000        0        0
#
# ...

# %%
df1.groupby("Country/Region").sum()
# Out:
#                    Province/State        Lat       Long  1/22/20  1/23/20  \
# Country/Region
# Afghanistan                     0  33.000000  65.000000        0        0
# Albania                         0  41.153300  20.168300        0        0
# Algeria                         0  28.033900   1.659600        0        0
# Andorra                         0  42.506300   1.521800        0        0
# Angola                          0 -11.202700  17.873900        0        0
# ...                           ...        ...        ...      ...      ...
# West Bank and Gaza              0  31.952200  35.233200        0        0
# Western Sahara                  0  24.215500 -12.885800        0        0
# Yemen                           0  15.552727  48.516388        0        0
# Zambia                          0 -15.416700  28.283300        0        0
# Zimbabwe                        0 -20.000000  30.000000        0        0
#
# ...

# %%
df1.groupby("Country/Region").sum("").loc["Canada"]
# Out:
# Province/State    AlbertaBritish ColumbiaGrand PrincessManitobaN...
# Lat                                                        671.7607
# Long                                                     -1237.6289
# 1/22/20                                                           0
# 1/23/20                                                           0
#                                         ...
# 6/11/20                                                       99159
# 6/12/20                                                       99595
# 6/13/20                                                      100043
# 6/14/20                                                      100404
# 6/15/20                                                      100763
# Name: Canada, Length: 149, dtype: object

# %%
df1.groupby("Country/Region").sum().loc['China',:]
# Out:
# Province/State    AnhuiBeijingChongqingFujianGansuGuangdongGuang...
# Lat                                                       1083.3367
# Long                                                      3684.4197
# 1/22/20                                                         548
# 1/23/20                                                         643
#                                         ...
# 6/11/20                                                       84216
# 6/12/20                                                       84228
# 6/13/20                                                       84286
# 6/14/20                                                       84335
# 6/15/20                                                       84378
# Name: China, Length: 149, dtype: object

# %%
df1[df1["Country/Region"]=="China"]
# Out:
#     Province/State Country/Region      Lat      Long  1/22/20  1/23/20  \
# 49           Anhui          China  31.8257  117.2264        1        9
# 50         Beijing          China  40.1824  116.4142       14       22
# 51       Chongqing          China  30.0572  107.8740        6        9
# 52          Fujian          China  26.0789  117.9874        1        5
# 53           Gansu          China  37.8099  101.0583        0        2
# 54       Guangdong          China  23.3417  113.4244       26       32
# 55         Guangxi          China  23.8298  108.7881        2        5
# 56         Guizhou          China  26.8154  106.8748        1        3
# 57          Hainan          China  19.1959  109.7453        4        5
# 58           Hebei          China  39.5490  116.1306        1        1
# 59    Heilongjiang          China  47.8620  127.7615        0        2
# 60           Henan          China  33.8820  113.6140        5        5
# ...

# %%
df1[df1["Country/Region"]=="China"]["1/23/20"].sum()
# Out:
# 643

# %%
df1["Long"].to_frame()
# Out:
#           Long
# 0    65.000000
# 1    20.168300
# 2     1.659600
# 3     1.521800
# 4    17.873900
# ..         ...
# 261   6.613081
# 262  48.516388
# 263  43.333300
# 264  71.276093
# 265  28.233608
#
# [266 rows x 1 columns]

# %%
df1.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '6/6/20', '6/7/20', '6/8/20', '6/9/20', '6/10/20', '6/11/20', '6/12/20',
#        '6/13/20', '6/14/20', '6/15/20'],
#       dtype='object', length=150)

# %%
len(df1.columns)
# Out:
# 150

# %%
df1.drop(["Lat","Long"],axis=1)
# Out:
#     Province/State         Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0              NaN            Afghanistan        0        0        0        0
# 1              NaN                Albania        0        0        0        0
# 2              NaN                Algeria        0        0        0        0
# 3              NaN                Andorra        0        0        0        0
# 4              NaN                 Angola        0        0        0        0
# ..             ...                    ...      ...      ...      ...      ...
# 261            NaN  Sao Tome and Principe        0        0        0        0
# 262            NaN                  Yemen        0        0        0        0
# 263            NaN                Comoros        0        0        0        0
# 264            NaN             Tajikistan        0        0        0        0
# 265            NaN                Lesotho        0        0        0        0
#
# ...

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=266, step=1)

# %%
len(df1.index)
# Out:
# 266

# %%
df1.index.names
# Out:
# FrozenList([None])

# %%
df1.size
# Out:
# 39900

# %%
df1.sort_values("Long")
# Out:
#             Province/State Country/Region      Lat      Long  1/22/20  \
# 245                  Yukon         Canada  64.2823 -135.0000        0
# 244  Northwest Territories         Canada  64.8255 -124.8457        0
# 36        British Columbia         Canada  49.2827 -123.1207        0
# 37          Grand Princess         Canada  37.6489 -122.6655        0
# 35                 Alberta         Canada  53.9333 -116.5765        0
# ..                     ...            ...      ...       ...      ...
# 9          New South Wales      Australia -33.8688  151.2093        0
# 11              Queensland      Australia -28.0167  153.4000        0
# 111          New Caledonia         France -20.9043  165.6180        0
# 170                    NaN    New Zealand -40.9006  174.8860        0
# 105                    NaN           Fiji -17.7134  178.0650        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  \
# ...

# %%
df1["6/6/20"].mean()      # 6/6/20 gününde tüm dünyadaki ortama enfekte sayısı
# Out:
# 25949.812030075187

# %%
df1[df1["6/6/20"] == df1["6/6/20"].max()]["Country/Region"].iloc[0]  #  6/6/20 tarihinde maximum enfekte sayısı US aitmiş.
# Out:
# 'US'

# %%
df1["6/6/20"].max()         #   6/6/20 tarihinde maximum enfekte sayısı
# Out:
# 1926538

# %%
df1["Country/Region"].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0                Afghanistan
# 1                    Albania
# 2                    Algeria
# 3                    Andorra
# 4                     Angola
#                ...
# 261    Sao Tome and Principe
# 262                    Yemen
# 263                  Comoros
# 264               Tajikistan
# 265                  Lesotho
# Name: Country/Region, Length: 266, dtype: object>

# %%
df1["Country/Region" ].value_counts()
# Out:
# Country/Region
# China             33
# Canada            14
# United Kingdom    11
# France            11
# Australia          8
#                   ..
# Honduras           1
# Hungary            1
# Iceland            1
# India              1
# Lesotho            1
# Name: count, Length: 188, dtype: int64

# %%
df1.shape
# Out:
# (266, 150)

# %%
df1.describe()
# Out:
#               Lat        Long     1/22/20     1/23/20     1/24/20     1/25/20  \
# count  266.000000  266.000000  266.000000  266.000000  266.000000  266.000000
# mean    21.148043   22.538640    2.086466    2.458647    3.537594    5.390977
# std     24.909990   70.466256   27.279200   27.377862   34.083035   47.434934
# min    -51.796300 -135.000000    0.000000    0.000000    0.000000    0.000000
# 25%      6.907750  -18.093125    0.000000    0.000000    0.000000    0.000000
# 50%     23.488100   20.972650    0.000000    0.000000    0.000000    0.000000
# 75%     41.143200   77.191525    0.000000    0.000000    0.000000    0.000000
# max     71.706900  178.065000  444.000000  444.000000  549.000000  761.000000
#
#            1/26/20      1/27/20      1/28/20      1/29/20  ...        6/6/20  \
# count   266.000000   266.000000   266.000000   266.000000  ...  2.660000e+02
# mean      7.962406    11.003759    20.969925    23.180451  ...  2.594981e+04
# ...

# %%
df1.iloc[0:10]["Country/Region"]       # ilk 10 satırın ülke bilgisi
# Out:
# 0            Afghanistan
# 1                Albania
# 2                Algeria
# 3                Andorra
# 4                 Angola
# 5    Antigua and Barbuda
# 6              Argentina
# 7                Armenia
# 8              Australia
# 9              Australia
# Name: Country/Region, dtype: object

# %%
df1.drop(columns=["Province/State"]) #Province/State sütünü silindi.
# Out:
#             Country/Region        Lat       Long  1/22/20  1/23/20  1/24/20  \
# 0              Afghanistan  33.000000  65.000000        0        0        0
# 1                  Albania  41.153300  20.168300        0        0        0
# 2                  Algeria  28.033900   1.659600        0        0        0
# 3                  Andorra  42.506300   1.521800        0        0        0
# 4                   Angola -11.202700  17.873900        0        0        0
# ..                     ...        ...        ...      ...      ...      ...
# 261  Sao Tome and Principe   0.186360   6.613081        0        0        0
# 262                  Yemen  15.552727  48.516388        0        0        0
# 263                Comoros -11.645500  43.333300        0        0        0
# 264             Tajikistan  38.861034  71.276093        0        0        0
# 265                Lesotho -29.609988  28.233608        0        0        0
#
# ...

# %%
df1[1:3]
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  6/10/20  \
# 1        0        0        0  ...    1232    1246    1263    1299     1341
# 2        0        0        0  ...   10050   10154   10265   10382    10484
#
#    6/11/20  6/12/20  6/13/20  6/14/20  6/15/20
# 1     1385     1416     1464     1521     1590
# 2    10589    10698    10810    10919    11031
#
# [2 rows x 150 columns]

# %%
import numpy as np 
import pandas as pd

# %%
recovered_dataset=pd.read_csv('C:/DATA/data/covid_veri/time_series_covid19_recovered_global.csv')

# %%
recovered_dataset
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 248            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 249            NaN                  Yemen  15.552727  48.516388        0
# 250            NaN                Comoros -11.645500  43.333300        0
# 251            NaN             Tajikistan  38.861034  71.276093        0
# 252            NaN                Lesotho -29.609988  28.233608        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  \
# ...

# %%
df2= pd.DataFrame(recovered_dataset)

# %%
df2
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 248            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 249            NaN                  Yemen  15.552727  48.516388        0
# 250            NaN                Comoros -11.645500  43.333300        0
# 251            NaN             Tajikistan  38.861034  71.276093        0
# 252            NaN                Lesotho -29.609988  28.233608        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  \
# ...

# %%
deaths_dataset=pd.read_csv('C:/DATA/data/covid_veri/time_series_covid19_deaths_global.csv')

# %%
deaths_dataset
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 263            NaN                Comoros -11.645500  43.333300        0
# 264            NaN             Tajikistan  38.861034  71.276093        0
# 265            NaN                Lesotho -29.609988  28.233608        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  \
# ...

# %%
df3= pd.DataFrame(deaths_dataset)

# %%
df3
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 263            NaN                Comoros -11.645500  43.333300        0
# 264            NaN             Tajikistan  38.861034  71.276093        0
# 265            NaN                Lesotho -29.609988  28.233608        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  \
# ...

# %%
import pandas as pd
import numpy as np

# %%
def compare_columns(df1,df2):
    return all (df1.columns == df2.columns)

# %%
print(compare_columns(recovered_dataset,infected_dataset))
print(compare_columns(recovered_dataset,infected_dataset))
# Out:
# True
# True

# %%
df1.drop(columns=["Lat","Long","Province/State"])
# Out:
#             Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0              Afghanistan        0        0        0        0        0
# 1                  Albania        0        0        0        0        0
# 2                  Algeria        0        0        0        0        0
# 3                  Andorra        0        0        0        0        0
# 4                   Angola        0        0        0        0        0
# ..                     ...      ...      ...      ...      ...      ...
# 261  Sao Tome and Principe        0        0        0        0        0
# 262                  Yemen        0        0        0        0        0
# 263                Comoros        0        0        0        0        0
# 264             Tajikistan        0        0        0        0        0
# 265                Lesotho        0        0        0        0        0
#
#      1/27/20  1/28/20  1/29/20  1/30/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  \
# ...

# %%
df2.drop(columns=["Lat","Long","Province/State"])
# Out:
#             Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0              Afghanistan        0        0        0        0        0
# 1                  Albania        0        0        0        0        0
# 2                  Algeria        0        0        0        0        0
# 3                  Andorra        0        0        0        0        0
# 4                   Angola        0        0        0        0        0
# ..                     ...      ...      ...      ...      ...      ...
# 248  Sao Tome and Principe        0        0        0        0        0
# 249                  Yemen        0        0        0        0        0
# 250                Comoros        0        0        0        0        0
# 251             Tajikistan        0        0        0        0        0
# 252                Lesotho        0        0        0        0        0
#
#      1/27/20  1/28/20  1/29/20  1/30/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  \
# ...

# %%
df3.drop(columns=["Lat","Long","Province/State"])
# Out:
#             Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0              Afghanistan        0        0        0        0        0
# 1                  Albania        0        0        0        0        0
# 2                  Algeria        0        0        0        0        0
# 3                  Andorra        0        0        0        0        0
# 4                   Angola        0        0        0        0        0
# ..                     ...      ...      ...      ...      ...      ...
# 261  Sao Tome and Principe        0        0        0        0        0
# 262                  Yemen        0        0        0        0        0
# 263                Comoros        0        0        0        0        0
# 264             Tajikistan        0        0        0        0        0
# 265                Lesotho        0        0        0        0        0
#
#      1/27/20  1/28/20  1/29/20  1/30/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  \
# ...

# %%
def make_frame(country:str):
    """Take country name as parameter, return infected, recovered, deaths values as timeseries table.
    pd.DataFrame()
    """
    pass

# %%
def make_frame(country:str):
    """Take country name as parameter, return infected, recovered, deaths values as timeseries table.
    
    """

    df = pd.DataFrame({
        'infected' : df_infected.loc[country],
        'recovered': df_recovered.loc[country],
        'deaths': df_deaths.loc[country]
    })
    df.index = pd.to_datetime(df.index, format='%m/%d/%y')
    return df

# %%
import matplotlib.pyplot as plt
